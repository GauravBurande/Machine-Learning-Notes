# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

# %%
soup = BeautifulSoup(webpage)

# %%
company = soup.find_all('div', class_='company-content-wrapper')

# %%
name = []
rating = []
reviews = []
ctype = []
hq = []
old = []
employees = []
desc = []

for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('p', class_='rating').text.strip())
    reviews.append(i.find('a', class_='review-count').text.strip())
    ctype.append(i.find_all('p', class_='infoEntity')[0].text.strip())
    hq.append(i.find_all('p', class_='infoEntity')[1].text.strip())
    old.append(i.find_all('p', class_='infoEntity')[2].text.strip())
    employees.append(i.find_all('p', class_='infoEntity')[3].text.strip())
    
    
    
d = {'name':name,'rating':rating,'reviews':reviews,'type':ctype,'hq':hq,'old':old,'employees':employees}

df = pd.DataFrame(d)

df
# Out:
#                    name rating          reviews     type  \
# 0                   TCS    3.9  (36.4k Reviews)   Public
# 1             Accenture    4.1  (24.6k Reviews)   Public
# 2             Cognizant    3.9  (22.7k Reviews)  Private
# 3            ICICI Bank    4.0  (29.5k Reviews)   Public
# 4             HDFC Bank    4.0  (30.4k Reviews)   Public
# 5                 Wipro    3.9  (21.1k Reviews)   Public
# 6             Capgemini    3.8  (18.1k Reviews)   Public
# 7      HCL Technologies    3.8  (17.9k Reviews)   Public
# 8               Infosys    4.0  (21.6k Reviews)   Public
# 9         Tech Mahindra    3.7  (17.1k Reviews)   Public
# 10              Genpact    4.0  (16.7k Reviews)  Private
# 11            Axis Bank    3.9  (15.6k Reviews)   Public
# 12         Reliance jio    4.0  (12.5k Reviews)   Public
# 13                  IBM    4.1  (12.6k Reviews)   Public
# 14  Larsen & Toubro ...    4.0  (15.9k Reviews)   Public
# 15        Vodafone Idea    4.2  (12.2k Reviews)   Public
# 16  Concentrix Corpo...    4.1  (12.1k Reviews)   Public
# 17               Amazon    4.2  (11.9k Reviews)  Private
# 18  HDB Financial Se...    4.0  (10.8k Reviews)  Private
# 19  Kotak Mahindra B...    3.9  (11.2k Reviews)   Public
# 20      Teleperformance    3.6   (8.3k Reviews)  Private
# 21        Bharti Airtel    4.1  (10.9k Reviews)   Public
# 22          Tata Motors    4.1   (7.8k Reviews)   Public
# 23  Reliance Industr...    4.0  (33.1k Reviews)   Public
# 24             Deloitte    4.0   (7.2k Reviews)  Private
# 25      Reliance Retail    4.1  (10.7k Reviews)  Private
# 26  Mahindra & Mahin...    4.1  (17.4k Reviews)   Public
# 27        IndusInd Bank    3.8   (5.7k Reviews)   Public
# 28                  WNS    3.7   (5.5k Reviews)  Private
# 29  Hinduja Global S...    3.9   (5.3k Reviews)   Public
#
#                                           hq            old  \
# 0              Mumbai,Maharashtra + 230 more   54 years old
# 1                   Dublin,Dublin + 126 more   33 years old
# 2               Teaneck,New Jersey + 85 more   28 years old
# 3              Mumbai,Maharashtra + 957 more   28 years old
# 4             Mumbai,Maharashtra + 1047 more   28 years old
# 5   Bangalore/Bengaluru,Karnataka + 244 more   77 years old
# 6                            Paris + 67 more   55 years old
# 7             Noida,Uttar Pradesh + 151 more   46 years old
# 8   Bangalore/Bengaluru,Karnataka + 115 more   41 years old
# 9                Pune,Maharashtra + 172 more   36 years old
# 10               New York,New York + 54 more   25 years old
# 11             Mumbai,Maharashtra + 940 more   29 years old
# 12        Navi Mumbai,Maharashtra + 866 more   15 years old
# 13                Armonk,New York + 105 more  111 years old
# 14             Mumbai,Maharashtra + 461 more   84 years old
# 15             Gandhinagar,Gujrat + 531 more    4 years old
# 16              Fremont,California + 56 more   39 years old
# 17             Seattle,Washington + 308 more   28 years old
# 18               Ahmedabad,Gujrat + 667 more   15 years old
# 19             Mumbai,Maharashtra + 437 more   19 years old
# 20                          Paris + 107 more   44 years old
# 21       Gurgaon/Gurugram,Haryana + 446 more   27 years old
# 22               Pune,Maharashtra + 365 more   77 years old
# 23        Navi Mumbai,Maharashtra + 376 more   49 years old
# 24              New York,New York + 126 more  177 years old
# 25        Navi Mumbai,Maharashtra + 452 more   16 years old
# 26             Mumbai,Maharashtra + 366 more   77 years old
# 27       Gurgaon/Gurugram,Haryana + 505 more   28 years old
# 28              Mumbai,Maharashtra + 19 more   26 years old
# 29   Bangalore/Bengaluru,Karnataka + 70 more   22 years old
#
#                        employees
# 0      1 Lakh+ Employees (India)
# 1      1 Lakh+ Employees (India)
# 2      1 Lakh+ Employees (India)
# 3   50k-1 Lakh Employees (India)
# 4      1 Lakh+ Employees (India)
# 5      1 Lakh+ Employees (India)
# 6      1 Lakh+ Employees (India)
# 7      1 Lakh+ Employees (India)
# 8      1 Lakh+ Employees (India)
# 9   50k-1 Lakh Employees (India)
# 10  50k-1 Lakh Employees (India)
# 11  50k-1 Lakh Employees (India)
# 12     10k-50k Employees (India)
# 13     1 Lakh+ Employees (India)
# 14     10k-50k Employees (India)
# 15     10k-50k Employees (India)
# 16     10k-50k Employees (India)
# 17     1 Lakh+ Employees (India)
# 18     1 Lakh+ Employees (India)
# 19     10k-50k Employees (India)
# 20  50k-1 Lakh Employees (India)
# 21      5k-10k Employees (India)
# 22  50k-1 Lakh Employees (India)
# 23     1 Lakh+ Employees (India)
# 24     10k-50k Employees (India)
# 25     1 Lakh+ Employees (India)
# 26     10k-50k Employees (India)
# 27     10k-50k Employees (India)
# 28     10k-50k Employees (India)
# 29     10k-50k Employees (India)

# %%
final = pd.DataFrame()

for j in range(1,11):
    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    webpage = requests.get(url).text
    soup = BeautifulSoup(webpage)
    company = soup.find_all('div', class_='company-content-wrapper')
    
    name = []
    rating = []
    reviews = []
    ctype = []
    hq = []
    old = []
    employees = []
    
    
    for i in company:
        name.append(i.find('h2').text.strip())
        rating.append(i.find('p', class_='rating').text.strip())
        reviews.append(i.find('a', class_='review-count').text.strip())
        ctype.append(i.find_all('p', class_='infoEntity')[0].text.strip())
        hq.append(i.find_all('p', class_='infoEntity')[1].text.strip())
        
        try:
            old.append(i.find_all('p', class_='infoEntity')[2].text.strip())
        except:
            old.append(np.nan)
            
        try:
            employees.append(i.find_all('p', class_='infoEntity')[3].text.strip())
        except:
            employees.append(np.nan)



    d = {'name':name,'rating':rating,'reviews':reviews,'type':ctype,'hq':hq,'old':old,'employees':employees}

    df = pd.DataFrame(d)
    final = final.append(df, ignore_index=True)
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_14104\974553855.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df, ignore_index=True)

# %%
final.sample(50)
# Out:
#                     name rating         reviews  \
# 62         Bajaj Finance    4.2  (3.2k Reviews)
# 258  GeBBS Healthcare...    3.8  (1.3k Reviews)
# 46       IDFC FIRST Bank    3.9  (3.9k Reviews)
# 166              Cummins    4.4  (1.8k Reviews)
# 55              NTT DATA    4.0  (6.9k Reviews)
# 125  Nagarjuna Constr...    4.1  (2.1k Reviews)
# 116         UnitedHealth    4.1  (3.6k Reviews)
# 276               Fiserv    3.9  (1.2k Reviews)
# 170  Schneider Electr...    4.2  (3.3k Reviews)
# 176  VE Commercial Ve...    4.1  (1.7k Reviews)
# 175  Intas Pharmaceut...    4.3  (1.7k Reviews)
# 221     Vishal Mega Mart    4.0  (1.5k Reviews)
# 149           Ford Motor    4.5  (2.1k Reviews)
# 145  ICICI Lombard Ge...    3.8  (1.9k Reviews)
# 232       Landmark Group    4.3  (4.2k Reviews)
# 295            Blue Star    4.1  (1.2k Reviews)
# 219            MRF Tyres    3.7  (1.5k Reviews)
# 213               Rivigo    3.9  (1.5k Reviews)
# 128  State Bank of In...    4.0    (2k Reviews)
# 158     L&T Construction    4.0  (1.9k Reviews)
# 281  Sapient Corporat...    3.9  (1.4k Reviews)
# 44   Sutherland Globa...    3.8  (4.3k Reviews)
# 267  Utkarsh Small Fi...    4.0  (1.3k Reviews)
# 138        Muthoot Group    3.6  (3.9k Reviews)
# 253  NIIT Technologie...    3.4  (1.3k Reviews)
# 169  Indiamart Interm...    3.8  (1.8k Reviews)
# 211        24/7 Customer    3.6  (1.5k Reviews)
# 203  Pidilite Industr...    4.4  (1.6k Reviews)
# 104         First Source    3.9  (2.4k Reviews)
# 214  Virtusa Consulti...    3.7  (1.5k Reviews)
# 239            Lifestyle    4.3  (1.4k Reviews)
# 95         Hero MotoCorp    4.3  (2.6k Reviews)
# 67          L&T Infotech    3.9  (3.1k Reviews)
# 144  Wipro Enterprise...    3.8  (1.9k Reviews)
# 250  Biocon Biologics...    4.0  (1.3k Reviews)
# 85       JP Morgan Chase    4.1  (2.7k Reviews)
# 70   Reliance Communi...    4.0  (3.4k Reviews)
# 180  Tata Teleservice...    4.1  (1.7k Reviews)
# 20       Teleperformance    3.6  (8.3k Reviews)
# 184          GlobalLogic    4.0  (1.7k Reviews)
# 226                Dabur    4.2  (1.4k Reviews)
# 181                 Atos    3.8  (5.7k Reviews)
# 199             DCB Bank    3.9  (1.6k Reviews)
# 143  Equitas Small Fi...    4.1  (1.9k Reviews)
# 45   ICICI Prudential...    4.1  (3.9k Reviews)
# 107            Delhivery    4.2  (2.4k Reviews)
# 132      Muthoot Fincorp    4.0    (2k Reviews)
# 131  Motherson Sumi S...    3.9  (3.1k Reviews)
# 275  Tata AIG General...    4.2  (1.2k Reviews)
# 193  Reliance Nippon ...    3.9  (1.6k Reviews)
#
#                               type  \
# 62                         Private
# 258                        Private
# 46                          Public
# 166     Columbus,Indiana + 73 more
# 55                         Private
# 125                         Public
# 116                        Private
# 276                        Private
# 170                        Private
# 176                        Private
# 175                        Private
# 221                        Private
# 149                         Public
# 145                         Public
# 232                        Private
# 295                         Public
# 219                         Public
# 213                        Private
# 128  Mumbai,Maharashtra + 290 more
# 158                         Public
# 281                        Private
# 44                         Private
# 267                         Public
# 138                         Public
# 253                         Public
# 169                        Private
# 211                        Private
# 203                         Public
# 104                         Public
# 214                        Private
# 239                        Private
# 95                          Public
# 67                          Public
# 144            Bangalore + 63 more
# 250                         Public
# 85                         Private
# 70                          Public
# 180                         Public
# 20                         Private
# 184                        Private
# 226                         Public
# 181                        Private
# 199                        Private
# 143                        Private
# 45                          Public
# 107                        Private
# 132                        Private
# 131                         Public
# 275                        Private
# 193                        Private
#
#                                                   hq  \
# 62                       Pune,Maharashtra + 549 more
# 258                 Culver City,California + 10 more
# 46                     Mumbai,Maharashtra + 302 more
# 166                                     60 years old
# 55                      Chiyoda City,Tokyo + 33 more
# 125      Hyderabad/Secunderabad,Telangana + 159 more
# 116                   Minnetonka,Minnesota + 11 more
# 276                   Brookfield,Wisconsin + 26 more
# 170                                  Paris + 60 more
# 176               Gurgaon/Gurugram,Haryana + 96 more
# 175                       Ahmedabad,Gujrat + 89 more
# 221                      Ahmedabad,Gujrat + 211 more
# 149                      Dearborn,Michigan + 96 more
# 145                    Mumbai,Maharashtra + 178 more
# 232                     Dubai Marina,Dubai + 95 more
# 295                     Mumbai,Maharashtra + 97 more
# 219                    Chennai,Tamil Nadu + 155 more
# 213                       Gurgaon,Haryana + 137 more
# 128                                    216 years old
# 158                               Chennai + 214 more
# 281                      New York,New York + 14 more
# 44                      Pittsford,New York + 38 more
# 267                Varanasi,Uttar Pradesh + 182 more
# 138              Wedel,Schleswig-holstein + 306 more
# 253                    Noida,Uttar Pradesh + 75 more
# 169                    Noida,Uttar Pradesh + 90 more
# 211                    San Jose,California + 16 more
# 203                    Mumbai,Maharashtra + 158 more
# 104                     Mumbai,Maharashtra + 43 more
# 214             Southborough,Massachusetts + 20 more
# 239          Bangalore/Bengaluru,Karnataka + 79 more
# 95               Gurgaon/Gurugram,Haryana + 244 more
# 67                      Mumbai,Maharashtra + 75 more
